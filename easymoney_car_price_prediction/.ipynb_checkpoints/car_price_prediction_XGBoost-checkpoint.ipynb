# %% [markdown]
# <h1  style='color:red;'><center>Car Price Prediction</center></h>

# %% [markdown]
# <h3  style='color:red;'>1. Import Dependencies</h3>

# %%
import sklearn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

from sklearn import linear_model
from sklearn import metrics

from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection  import cross_val_score
from sklearn import model_selection
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
#export ML model
import pickle

# %% [markdown]
# <h3  style='color:red;'>2. Load Data</h3>

# %%
#import the dataset
df = pd.read_csv('dataset/vehicles.csv')

# %%
#set display all columns
pd.set_option('display.max_columns',80)
#set display all rows
#pd.set_option('display.max_rows',80)

# %% [markdown]
# <h3  style='color:red;'>3. Data Cleansing | Wrnagling</h3>

# %%
#check all info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
#  17  type          334022 non-null  object
#  18  paint_color   296677 non-null  object
#  19  image_url     426812 non-null  object
#  20  description   426810 non-null  object
#  21  county        0 non-null       float64
#  22  state         426880 non-null  object
#  23  lat           420331 non-null  float64
#  24  long          420331 non-null  float64
#  25  posting_date  426812 non-null  object
# dtypes: float64(5), int64(2), object(19)
# memory usage: 84.7+ MB

# %%
#drop the features of dataset
df.drop(['url','region_url','image_url','description','lat','long','id','region','county','size',
        'VIN','state', 'posting_date','condition'], axis=1, inplace=True)

# %%
#assign data as df
data = df.copy()

# %%
#select 2000 up 
data = data[data['year'] > 1999]
data = data[data['price'] > 3000]

# %%
#check rows and columns number
data.shape
# Out:
# (340830, 12)

# %%
#check null or not
data.isnull().any()
# Out:
# price           False
# year            False
# manufacturer     True
# model            True
# cylinders        True
# fuel             True
# odometer         True
# title_status     True
# transmission     True
# drive            True
# type             True
# paint_color      True
# dtype: bool

# %%
#sum all null values in each featues
data.isnull().sum()
# Out:
# price                0
# year                 0
# manufacturer     10038
# model             2664
# cylinders       143049
# fuel              2263
# odometer          1937
# title_status      6052
# transmission      1683
# drive           101491
# type             66957
# paint_color      95367
# dtype: int64

# %%
#drop the null values
data.dropna(axis=0, inplace=True)

# %%
#drop other values
data.drop(data.loc[data['transmission']=='other'].index, inplace=True)
data.drop(data.loc[data['type']=='other'].index, inplace=True)

# %%
#sum all null values in each featues
data.isnull().sum()
# Out:
# price           0
# year            0
# manufacturer    0
# model           0
# cylinders       0
# fuel            0
# odometer        0
# title_status    0
# transmission    0
# drive           0
# type            0
# paint_color     0
# dtype: int64

# %%
#check samples after cleansing
data.shape
# Out:
# (114605, 12)

# %%
#check data type in each features
data.dtypes
# Out:
# price             int64
# year            float64
# manufacturer     object
# model            object
# cylinders        object
# fuel             object
# odometer        float64
# title_status     object
# transmission     object
# drive            object
# type             object
# paint_color      object
# dtype: object

# %%
#change data type
data.price = data.price.astype('float')
data.year = data.year.astype('int')

# %%
#replace 
data.cylinders = data.cylinders.astype(str)
data.cylinders = data.cylinders.str.replace('cylinders','')
data.cylinders = data.cylinders.str.replace('other','0')
data.cylinders = data.cylinders.astype(int)

# %%
#rename the features
data.rename(columns={
    'price':'price',
    'year':'year',
    'manufacturer':'manufacturer',
    'model':'model',
    'cylinders':'cylinder',
    'fuel':'fuel',
    'odometer':'kms_driven',
    'title_status':'status',
    'transmission':'transmission',
    'drive':'drive_wheel',
    'type':'body_type',
    'paint_color':'colour'
}, inplace=True)

# %%
# convert model datatype
data.model = data.model.astype(str)

# %%
#drop car value count under 100
drop_model_car = data['model'].value_counts()
data = data[~data['model'].isin(drop_model_car[drop_model_car < 100].index)]

# %%
#replace other by petrol
data.fuel = data.fuel.replace('other','petrol')

# %%
print("**" * 56)
print(data.year.unique())
print("**" * 56)
print("Min Year", data.year.min())
print("**" * 56)
print("Max Year",data.year.max())
print("**" * 56)
# Out:
# ****************************************************************************************************************
# [2013 2019 2004 2012 2003 2008 2006 2011 2014 2007 2009 2017 2010 2005
#  2016 2021 2002 2018 2001 2015 2020 2000]
# ****************************************************************************************************************
# Min Year 2000
# ****************************************************************************************************************
# Max Year 2021
# ****************************************************************************************************************

# %%
#replace manufacturer 
data.manufacturer = data.manufacturer.str.replace('-',' ')

# %%
print("**" * 56)
print(data.manufacturer.unique())
print("**" * 56)
# Out:
# ****************************************************************************************************************
# ['ford' 'toyota' 'honda' 'chrysler' 'jeep' 'nissan' 'buick' 'hyundai'
#  'gmc' 'chevrolet' 'volvo' 'ram' 'dodge' 'kia' 'volkswagen' 'acura'
#  'cadillac' 'bmw' 'lexus' 'mercedes benz' 'lincoln' 'subaru' 'audi'
#  'pontiac' 'rover' 'mazda' 'mitsubishi' 'mini']
# ****************************************************************************************************************

# %%
print("**" * 56)
print("Number Of Model Car - Unique Values :",len(data['model'].value_counts()))
print("**" * 56)
# Out:
# ****************************************************************************************************************
# Number Of Model Car - Unique Values : 197
# ****************************************************************************************************************

# %%
print("**" * 56)
print(data.cylinder.value_counts())
print("**" * 56)
# Out:
# ****************************************************************************************************************
# 4     23999
# 6     19854
# 8     14996
# 5       394
# 0       208
# 10      196
# 3        63
# 12        3
# Name: cylinder, dtype: int64
# ****************************************************************************************************************

# %%
print("**" * 56)
print(data.fuel.value_counts())
print("**" * 56)
# Out:
# ****************************************************************************************************************
# gas         54943
# diesel       3654
# hybrid        621
# petrol        491
# electric        4
# Name: fuel, dtype: int64
# ****************************************************************************************************************

# %%
print("**" * 56)
print("MAX Meters",data.kms_driven.max())
print("**" * 56)
print("MIN Meters",data.kms_driven.min())
print("**" * 56)
print("AVERAGE Meters",data.kms_driven.mean())
print("**" * 56)
# Out:
# ****************************************************************************************************************
# MAX Meters 9999999.0
# ****************************************************************************************************************
# MIN Meters 0.0
# ****************************************************************************************************************
# AVERAGE Meters 105358.54410262422
# ****************************************************************************************************************

# %%
#print("**" * 56)
#print(data.condition.value_counts())
#print("**" * 56)

# %%
print("**" * 56)
print(data.status.value_counts())
print("**" * 56)
# Out:
# ****************************************************************************************************************
# clean         56890
# rebuilt        1723
# salvage         681
# lien            403
# missing          11
# parts only        5
# Name: status, dtype: int64
# ****************************************************************************************************************

# %%
print("**" * 56)
print(data.transmission.value_counts())
print("**" * 56)
# Out:
# ****************************************************************************************************************
# automatic    56897
# manual        2816
# Name: transmission, dtype: int64
# ****************************************************************************************************************

# %%
print("**" * 56)
print(data.drive_wheel.value_counts())
print("**" * 56)
# Out:
# ****************************************************************************************************************
# 4wd    26678
# fwd    24216
# rwd     8819
# Name: drive_wheel, dtype: int64
# ****************************************************************************************************************

# %%
print("**" * 56)
print(data.body_type.value_counts())
print("**" * 56)
# Out:
# ****************************************************************************************************************
# sedan          18204
# SUV            17177
# truck          10117
# pickup          5876
# coupe           2063
# wagon           1652
# hatchback       1463
# van             1343
# mini-van        1222
# convertible      457
# offroad          133
# bus                6
# Name: body_type, dtype: int64
# ****************************************************************************************************************

# %%
print("**" * 56)
print(data.colour.value_counts())
print("**" * 56)
# Out:
# ****************************************************************************************************************
# white     13699
# black     11366
# silver     9235
# grey       7915
# blue       5906
# red        5518
# custom     2780
# brown      1351
# green      1182
# yellow      366
# orange      269
# purple      126
# Name: colour, dtype: int64
# ****************************************************************************************************************

# %%
data.columns
# Out:
# Index(['price', 'year', 'manufacturer', 'model', 'cylinder', 'fuel',
#        'kms_driven', 'status', 'transmission', 'drive_wheel', 'body_type',
#        'colour'],
#       dtype='object')

# %%
#check outlier
f, axes = plt.subplots(ncols=2, figsize=(25, 6))

sns.boxplot(y=data['price'], ax=axes[0])
sns.boxplot(y=data['kms_driven'], ax=axes[1])
plt.ylabel('Meter - In Million')
plt.show()

# %%
from scipy.stats import zscore

for i in range(1,6):
    #remove outliers
    data['meter_outliers'] = zscore(data['kms_driven'])
    #define meter outliers
    data[(data.meter_outliers > 3.0) | (data.meter_outliers < -3.0) ]
    #drop outliers
    data = data.drop(data[(data.meter_outliers > 3.0) | (data.meter_outliers < -3.0) ].index)

# %%
for i in range(1,6):    
    #remove price outliers
    data['price_outliers'] = zscore(data['price'])
    #define meter outliers
    data[(data.price_outliers > 3.0) | (data.price_outliers < -3.0) ]
    #drop outliers
    data = data.drop(data[(data.price_outliers > 3.0) | (data.price_outliers < -3.0) ].index)

# %%
f, axes = plt.subplots(ncols=2, figsize=(25, 6))
sns.boxplot(y=data['kms_driven'], color='green',ax=axes[0])
plt.title('ODO Meter', fontweight='bold')
sns.boxplot(y=data['price'], color='green',ax=axes[1])
plt.title('Price', fontweight='bold')
plt.show()

# %%
#drop meter outliers column
data.drop('meter_outliers', axis=1, inplace=True)
data.drop('price_outliers', axis=1, inplace=True)

# %%
#drop cylinder = 0
data = data.drop(data[(data.cylinder == 0)].index)

# %%
data.describe(include='all')
# Out:
#                price          year manufacturer  model      cylinder   fuel  \
# count   57508.000000  57508.000000        57508  57508  57508.000000  57508
# unique           NaN           NaN           28    197           NaN      5
# top              NaN           NaN         ford  f-150           NaN    gas
# freq             NaN           NaN        11781   2298           NaN  53773
# mean    15998.892711   2012.281665          NaN    NaN      5.643545    NaN
# std     10223.575719      4.586639          NaN    NaN      1.596465    NaN
# min      3050.000000   2000.000000          NaN    NaN      3.000000    NaN
# 25%      7900.000000   2009.000000          NaN    NaN      4.000000    NaN
# 50%     12999.000000   2013.000000          NaN    NaN      6.000000    NaN
# 75%     21995.000000   2016.000000          NaN    NaN      6.000000    NaN
# max     47000.000000   2021.000000          NaN    NaN     12.000000    NaN
#
#            kms_driven status transmission drive_wheel body_type colour
# count    57508.000000  57508        57508       57508     57508  57508
# unique            NaN      6            2           3        12     12
# top               NaN  clean    automatic         4wd     sedan  white
# freq              NaN  54741        54828       24908     18103  12981
# mean    104508.466126    NaN          NaN         NaN       NaN    NaN
# std      54500.248767    NaN          NaN         NaN       NaN    NaN
# min          0.000000    NaN          NaN         NaN       NaN    NaN
# 25%      63719.750000    NaN          NaN         NaN       NaN    NaN
# 50%     103090.000000    NaN          NaN         NaN       NaN    NaN
# 75%     141000.000000    NaN          NaN         NaN       NaN    NaN
# max     267680.000000    NaN          NaN         NaN       NaN    NaN

# %%
plt.figure(figsize=(15,5))
correlation = data.corr(method='pearson')
sns.heatmap(correlation,xticklabels=correlation.columns.values,
           yticklabels=correlation.columns.values)
plt.show()

# %%
# calculate Pearson's correlation
#from scipy.stats import pearsonr
#corr, _ = pearsonr(data['price'], data['year'])
#print('Pearsons correlation: %.3f' % corr)

# %%
year_list = list(range(2000, 2025))

vehicles_year = data[data.year.astype(int).isin(year_list)]
#vehicles_odo = vehicles_prc[(vehicles_prc.odometer >100) & (vehicles_prc.odometer <=200000)]

# Plot again to visualize distribution
f, ax = plt.subplots(figsize=(15, 5))
ax.set_title('Price VS Year', pad=12, fontweight='bold')
fig = sns.boxplot(x=data.year.astype(int), y='price', data=vehicles_year)
plt.xticks(rotation=45);

# %% [markdown]
# <h3 style='color:red;'>4. Data Preprocessing</h3>

# %%
#define a variable
vehicle_dummies = data[['price',
                        'year',
                        'manufacturer',
                        'cylinder',
                        'model',
                        'fuel',
                        'kms_driven',
                        'status',
                        'transmission',
                        'drive_wheel',
                        'body_type',
                        'colour']]

# %%
# Defining the map function
#this model doesnt apply 
def cat_dummies(x,data):
    va_dummies = pd.get_dummies(data[x], drop_first = False)
    data = pd.concat([data, va_dummies], axis = 1)
    data.drop([x], axis = 1, inplace = True)
    return data

# %%
#print the dtype of each columns
vehicle_dummies.dtypes
# Out:
# price           float64
# year              int64
# manufacturer     object
# cylinder          int64
# model            object
# fuel             object
# kms_driven      float64
# status           object
# transmission     object
# drive_wheel      object
# body_type        object
# colour           object
# dtype: object

# %%
# Applying the function to the cat_demmies
#vehicle_dummies = cat_dummies('manufacturer',vehicle_dummies)
#vehicle_demmies = cat_dummies('model',vehicle_demmies)
#vehicle_dummies = cat_dummies('condition',vehicle_dummies)
#vehicle_dummies = cat_dummies('fuel',vehicle_dummies)
#vehicle_dummies = cat_dummies('status',vehicle_dummies)
#vehicle_dummies = cat_dummies('transmission',vehicle_dummies)
#vehicle_dummies = cat_dummies('drive_wheel',vehicle_dummies)
#vehicle_dummies = cat_dummies('body_type',vehicle_dummies)
#vehicle_dummies = cat_dummies('colour',vehicle_dummies)

# %% [markdown]
# <h3 style='color:red;'>**************** Feature Scaling ****************</h3>

# %%
from sklearn.preprocessing import LabelEncoder
label_enconder = LabelEncoder()

#label encoder for model features
#replace 1-1XX to model features
#vehicle_dummies.price = label_enconder.fit_transform(vehicle_dummies.price)
#vehicle_dummies.year = label_enconder.fit_transform(vehicle_dummies.year)
vehicle_dummies.manufacturer = label_enconder.fit_transform(vehicle_dummies.manufacturer)
vehicle_dummies.model = label_enconder.fit_transform(vehicle_dummies.model)
#vehicle_dummies.condition = label_enconder.fit_transform(vehicle_dummies.condition)
#vehicle_dummies.cylinder = label_enconder.fit_transform(vehicle_dummies.cylinder)
vehicle_dummies.fuel = label_enconder.fit_transform(vehicle_dummies.fuel)
#vehicle_dummies.kms_driven = label_enconder.fit_transform(vehicle_dummies.kms_driven)
vehicle_dummies.status = label_enconder.fit_transform(vehicle_dummies.status)
vehicle_dummies.transmission = label_enconder.fit_transform(vehicle_dummies.transmission)
vehicle_dummies.drive_wheel = label_enconder.fit_transform(vehicle_dummies.drive_wheel)
vehicle_dummies.body_type = label_enconder.fit_transform(vehicle_dummies.body_type)
vehicle_dummies.colour = label_enconder.fit_transform(vehicle_dummies.colour)

# %%
#check rows and columns
vehicle_dummies.shape
# Out:
# (57508, 12)

# %%
#print the columns
print("Number Of Columns:", len(vehicle_dummies.columns))
# Out:
# Number Of Columns: 12

# %%
#print the dtype of each columns
vehicle_dummies.dtypes
# Out:
# price           float64
# year              int64
# manufacturer      int64
# cylinder          int64
# model             int64
# fuel              int64
# kms_driven      float64
# status            int64
# transmission      int64
# drive_wheel       int64
# body_type         int64
# colour            int64
# dtype: object

# %%
#use train test split function
# np.random.seed(0) makes the random numbers predictable
np.random.seed(0)
data_train, data_test = train_test_split(vehicle_dummies, test_size = 0.3, random_state = 100)

# %%
data_train.shape
# Out:
# (40255, 12)

# %%
data_test.shape
# Out:
# (17253, 12)

# %%
#features selecting of vihecle 
#num_variables = ['price', 'year', 'model', 'cylinder', 'kms_driven', 'acura', 'audi',
#       'bmw', 'buick', 'cadillac', 'chevrolet', 'chrysler', 'dodge', 'ford',
#       'gmc', 'honda', 'hyundai', 'jeep', 'kia', 'lexus', 'lincoln', 'mazda',
#       'mercedes benz', 'mini', 'nissan', 'pontiac', 'ram', 'subaru', 'toyota',
#       'volkswagen', 'excellent', 'fair', 'good', 'like new', 'new', 'salvage',
#       'diesel', 'electric', 'gas', 'hybrid', 'petrol', 'clean', 'lien',
#       'missing', 'parts only', 'rebuilt', 'salvage', 'automatic', 'manual',
#       '4wd', 'fwd', 'rwd', 'SUV', 'bus', 'convertible', 'coupe', 'hatchback',
#       'mini-van', 'offroad', 'pickup', 'sedan', 'truck', 'van', 'wagon',
#       'black', 'blue', 'brown', 'custom', 'green', 'grey', 'orange', 'purple',
#       'red', 'silver', 'white', 'yellow']

# %%
#let's scale the features
#scaler = MinMaxScaler()
#data_train[num_variables] = scaler.fit_transform(data_train[num_variables])
#data_test[num_variables] = scaler.fit_transform(data_test[num_variables])

# %%
plt.figure(figsize=(20,5))
plt.plot(data['price'][0:100], color='b')
plt.title("Car Price", fontweight='bold')
plt.show()

# %% [markdown]
# <h3  style='color:red;'>5. Train Model</h3>

# %%
plt.figure(figsize=(15,10))
correlation_train = data_train.corr(method='pearson')
sns.heatmap(correlation_train,
           xticklabels=correlation_train.columns.values,
           yticklabels=correlation_train.columns.values, annot=True)
plt.show()

# %%
#check statistic description
data_train.describe()
# Out:
#               price          year  manufacturer      cylinder         model  \
# count  40255.000000  40255.000000  40255.000000  40255.000000  40255.000000
# mean   15964.441833   2012.265880     11.957322      5.645162     93.162464
# std    10195.123225      4.601174      7.432739      1.595470     56.055468
# min     3050.000000   2000.000000      0.000000      3.000000      0.000000
# 25%     7900.000000   2009.000000      7.000000      4.000000     43.000000
# 50%    12999.000000   2013.000000      9.000000      6.000000     92.000000
# 75%    21995.000000   2016.000000     20.000000      6.000000    145.000000
# max    47000.000000   2021.000000     27.000000     10.000000    196.000000
#
#                fuel     kms_driven        status  transmission   drive_wheel  \
# count  40255.000000   40255.000000  40255.000000  40255.000000  40255.000000
# mean       1.934667  104549.629189      0.182586      0.047472      0.717004
# std        0.474211   54538.140273      0.857630      0.212650      0.707407
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%        2.000000   63900.000000      0.000000      0.000000      0.000000
# 50%        2.000000  103302.000000      0.000000      0.000000      1.000000
# 75%        2.000000  141200.000000      0.000000      0.000000      1.000000
# max        4.000000  267680.000000      5.000000      1.000000      2.000000
#
#           body_type        colour
# count  40255.000000  40255.000000
# mean       5.482574      5.535387
# std        3.822630      3.962572
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        8.000000      5.000000
# 75%        8.000000      9.000000
# max       11.000000     11.000000

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40255 entries, 267095 to 284056
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         40255 non-null  float64
#  1   year          40255 non-null  int64
#  2   manufacturer  40255 non-null  int64
#  3   cylinder      40255 non-null  int64
#  4   model         40255 non-null  int64
#  5   fuel          40255 non-null  int64
#  6   kms_driven    40255 non-null  float64
#  7   status        40255 non-null  int64
#  8   transmission  40255 non-null  int64
#  9   drive_wheel   40255 non-null  int64
#  10  body_type     40255 non-null  int64
#  11  colour        40255 non-null  int64
# dtypes: float64(2), int64(10)
# memory usage: 4.0 MB

# %%
#Dividing data train into x and y variables
Y = data_train.pop('price')
X = data_train

# %%
print(X.shape)
print(Y.shape)
# Out:
# (40255, 11)
# (40255,)

# %%
X.columns
# Out:
# Index(['year', 'manufacturer', 'cylinder', 'model', 'fuel', 'kms_driven',
#        'status', 'transmission', 'drive_wheel', 'body_type', 'colour'],
#       dtype='object')

# %%
#Apply train_test_split funtion to random dataset
x_train, x_test, y_train, y_test = train_test_split(X,Y , test_size=0.3, random_state=123)

# %%
#if len(x_train.shape) < 2:
#    x_train = np.array(x_train).reshape(-1,1)
#    x_test = np.array(x_test).reshape(-1,1)

# %% [markdown]
# <h3 style='color:red;'>XGBoost - XGBoost - XGBoost - XGBoost</h3>

# %%
# Define a dataframe to summarize accuracies for later
algo_list = ['XGBoost']
acc_cols = ['Training Accuracy', 'Testing Accuracy']


#set it as dataframe
acc_df = pd.DataFrame(columns=acc_cols, index=algo_list)

#define accuracy dataframe
acc_df.index.name='Algorithm'

# %%
def regression_metrics(pred_model, x_train, x_test, y_train, y_test):

    # Get predicted values on x_test
    y_pred = pred_model.predict(x_test)

    #1 & 2 Coefficient of Determination (R² & Adjusted R²)
    r2 = metrics.r2_score(y_pred=y_pred, y_true=y_test)
    adj_r2 = 1 - (1-r2)*(len(y_train)-1)/(len(y_train)-x_train.shape[1]-1)

    print(f"R²\t\t: {r2}")
    print(f"Adjusted R²\t: {adj_r2}")

   
    mse = metrics.mean_squared_error(y_pred=y_pred, y_true=y_test, squared=True)
    rmse = metrics.mean_squared_error(y_pred=y_pred, y_true=y_test, squared=False)

    print(f"MSE\t: {mse}")
    print(f"RMSE\t: {rmse}")

    mae = metrics.mean_absolute_error(y_pred=y_pred, y_true=y_test)
    print(f"MAE\t: {mae}")
    
    # Return Accuracy
    train_acc = round(pred_model.score(x_train, y_train)*100, 2)
    test_acc = round(pred_model.score(x_test, y_test)*100, 2)

    return (train_acc, test_acc)

# %%
# XGBoost
# Optimized Gradient Boosting algorithm through parallel processing, tree-pruning,
# handling missing values and regularization to avoid overfitting/bias

import xgboost as xgb

xgb_reg = xgb.XGBRegressor(verbosity=0) 
model = xgb_reg.fit(x_train, y_train)
print(model)

#xgb_acc = regression_metrics(xgb_reg, x_train, x_test, y_train, y_test)
#acc_df.loc['XGBoost'] = xgb_acc
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %% [markdown]
# <h3 style='color:red;'>6. Evaluation Model</h3>

# %%
#Try to prediction & test
y_prediction = model.predict(x_test)

# %%
#check the result
y_prediction_values = pd.DataFrame(list(zip(y_test[0:10], y_prediction[0:10])), 
                                     columns=['Y_Test', 'Y_Predicted'])
y_prediction_values.head(5)
# Out:
#     Y_Test   Y_Predicted
# 0   4399.0   3582.955566
# 1   6900.0   7713.773926
# 2  36000.0  33933.761719
# 3   8500.0   6892.378906
# 4   4995.0   4444.598633

# %%
print("*" * 20, "XGBoost Algorithm","*"*20)
model.fit(x_train, y_train)
model_acc = regression_metrics(model, x_train, x_test, y_train, y_test)
acc_df.loc['XGBoost'] = model_acc
# Out:
# ******************** XGBoost Algorithm ********************
# R²		: 0.9153394229318516
# Adjusted R²	: 0.9153063594387126
# MSE	: 8663738.491073847
# RMSE	: 2943.4229208650677
# MAE	: 1997.937635351789

# %%
#Check train data score of model
print("*" * 20, "Train Set - Score","*"*20)
train_score = model.score(x_train, y_train)
print("Model Score:", train_score)
print("**" * 10)
print("Model Score (%) :", train_score * 100)
# Out:
# ******************** Train Set - Score ********************
# Model Score: 0.9486310458046328
# ********************
# Model Score (%) : 94.86310458046327

# %%
#Check test data score of model
print("*" * 20, "Test Set - Score","*"*20)
test_score = model.score(x_test, y_test)
print("Model Score:", test_score)
print("**" * 10)
print("Model Score (%) :", test_score * 100)
# Out:
# ******************** Test Set - Score ********************
# Model Score: 0.9153394229318516
# ********************
# Model Score (%) : 91.53394229318515

# %% [markdown]
# <h3 style='color:red;'>**************** Plot The Result ****************</h3>

# %%
#Plot the results 
#Plot data ft scatter plot
#ravel() function can solve the problem replace to values() function

fig, ax = plt.subplots(figsize=(20,6))
ax.scatter(y_test, y_prediction, color='#51ABF7', marker='*')

#Draw a regression line
y_test, y_prediction = y_test.ravel().reshape(-1,1), y_prediction.ravel().reshape(-1,1)
ax.plot(y_test, LinearRegression().fit(y_test, y_prediction).predict(y_test), color='r')
plt.title("Car $ Prediction - XGBoost", color="#065164",fontsize='15', fontweight='bold')
plt.legend(['Estimated Regression Line', 'Observation Data'])
plt.ylabel("Car Price")
plt.show()

# %%
#set it as dataframe
prediction_values = pd.DataFrame(list(zip(y_prediction, y_test)), columns=['predicted_car_price', 
                                                                           'real_car_price'])

plt.figure(figsize=(20, 5))
plt.plot(y_test[0:150].ravel(), label='Real values', color='#51ABF7')
plt.plot(prediction_values['predicted_car_price'][0:150].ravel(), label='Predicted Values', color='#F91AAF')

plt.title('Car Price - Lost Function - Y Test VS Y Prediction',color="#065164",fontsize='15', fontweight='bold')
plt.legend(loc=1)
plt.show()

# %% [markdown]
# <h3 style='color:red;'>**************** Hyperparameter Tuning ****************</h3>

# %%
#Define X,y for train_test_split
x_val = data_test.drop(['price'], axis=1)
y_val = data_test['price']

# %%
#Apply k-fold cross validation
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection  import cross_val_score
from sklearn import model_selection

# %%
#set cross validation
#n_split = 5
# test_size = 0.3
#cv = ShuffleSplit(n_splits=5 , test_size=0.3 , random_state=10)
kfold = model_selection.KFold(n_splits=30, random_state=7,shuffle=True)  #,shuffle=True)

# %%
#process cross validation 
#apply 5-vold cross validation to linear regression
cross_validation_score = cross_val_score(model, x_val, y_val, cv=kfold)
#print the result
print("++" * 58)
print("Number of Score in each Iteration: ")
print("++" * 58)
for i,j in enumerate(cross_validation_score):
    print(i,"/",j)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Number of Score in each Iteration:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 0 / 0.9098254205308812
# 1 / 0.9135104416257663
# 2 / 0.9277848069933862
# 3 / 0.9129428795577784
# 4 / 0.9283942224161463
# 5 / 0.9198090065673519
# 6 / 0.9142421319295203
# 7 / 0.9285879436764994
# 8 / 0.9129094326610665
# 9 / 0.9090487554120412
# 10 / 0.9055985249436396
# 11 / 0.9128385689605698
# 12 / 0.9058240055474768
# 13 / 0.8979348267341077
# 14 / 0.925477100310847
# 15 / 0.9283400671013352
# 16 / 0.9139500983822558
# 17 / 0.9075695824553129
# 18 / 0.8922672839197681
# 19 / 0.9025081995576294
# 20 / 0.8971113743362132
# 21 / 0.908333187875887
# 22 / 0.9240787061014304
# 23 / 0.9182164832507906
# 24 / 0.8950508387091193
# 25 / 0.9329318505198485
# 26 / 0.9116634231072477
# 27 / 0.9203029050499789
# 28 / 0.9116796925568074
# 29 / 0.918366504395632

# %%
#select best model accuracy score
print("Best Model Accuray Score in K-Fold Cross Validation")
print(cross_validation_score.max())
# Out:
# Best Model Accuray Score in K-Fold Cross Validation
# 0.9329318505198485

# %%
#make a prediction on data validation
y_val_predict = model.predict(x_val)

# %%
#Plot the results 
#Plot data ft scatter plot
#ravel() function can solve the problem replace to values() function

fig, ax = plt.subplots(figsize=(20,6))
ax.scatter(y_val, y_val_predict, color='#F91AAF', marker='*')

#Draw a regression line
y_val, y_val_predict = y_val.ravel().reshape(-1,1), y_val_predict.ravel().reshape(-1,1)
ax.plot(y_val, LinearRegression().fit(y_val, y_val_predict).predict(y_val), color='b')
#ax.set_ylim([5000,50000])
plt.title("Car $ Prediction (XGBoost) - Validation Data", color="#065164",fontsize='15', fontweight='bold')
plt.legend(['Estimated Regression Line', 'Observation Data'])
plt.ylabel("Car Price")
plt.show()

# %%
#from scipy.stats import linregress
#slope,intercept,r,p_value,std_err = linregress(x_train,y_train)
#a = [slope,intercept]
#print('R^2 linregress = '+str(r**2))

# %% [markdown]
# <h3 style='color:red;'>**************** Model Testing ****************</h3>

# %%
#create a function to make the prediction
def car_price_prediction(year, manufacturer, cylinder, model, fuel, kms_driven, status,tranmission, 
                         drive_wheel, body_type,colour):
    data = [[year, manufacturer, cylinder, model, fuel, kms_driven, status,tranmission, drive_wheel, 
             body_type,colour]]
    
    data = pd.DataFrame(data)
    
    #data = np.shape(data)
    #data = np.asarray(data).shape
    
    result = model.predict(data)

    print("$$" * 58)
    print("\t\t\t\t\t The Car Price Prediction ($) :") 
    print("$$" * 58)
    print()
    if result < 0:
        print("Base On Your Car's Information, Model Doesn't Work For It")
    else:
        return result

# %%
#khmer24 - car's data 
#print(car_price_prediction(2002 ,1, 6, 1, 3,1000, 0,0,1,1,3))

# %%
#Test on Khmer24 Car dataset
new_samples_1 = x_test.head()
new_prediction_1 = model.predict(new_samples_1)
for i in new_prediction_1:
    print(i)
# Out:
# 3582.9556
# 7713.774
# 33933.76
# 6892.379
# 4444.5986

# %%
new_samples_list = [[2002 ,1, 6, 1, 3,1000, 0,0,1,1,3],
                [2017 ,23, 6, 3, 2,2500.0, 0,0,1,10,8],
                [2018 ,4, 8, 5, 3,2500.0, 2,4,3,4,3],
                [2002 ,4, 8, 5, 3,2500, 2,4,3,4,3],
                [2013,3,8,7,2,11843.0,0,0,0,3,0]]
new_samples_2 = pd.DataFrame(new_samples_list)
new_prediction_2 = model.predict(new_samples_2)
for i in new_prediction_2:
    print(i)
# Out:
# 6247.5596
# 27545.955
# 40800.387
# 17892.533
# 33289.203

# %%
#export ml model
with open('car_price_prediction_xgboost.pickle', 'wb') as f:
    #model 
    pickle.dump(model, f)

# %%
model_file = open("car_price_prediction_xgboost.pickle",'rb')
best_model = pickle.load(model_file)                         
result = best_model.predict(new_samples_2)
for i in result:
    print(i)
# Out:
# 6247.5596
# 27545.955
# 40800.387
# 17892.533
# 33289.203

# %%
data_train.dtypes
# Out:
# year              int64
# manufacturer      int64
# cylinder          int64
# model             int64
# fuel              int64
# kms_driven      float64
# status            int64
# transmission      int64
# drive_wheel       int64
# body_type         int64
# colour            int64
# dtype: object

# %%
[
    {
        "year": 2002, 
        "manufacturer": 1,
        "cylinder": 6,
        "model": 1, 
        "fuel": 3, 
        "kms_driven": 1000, 
        "status":0, 
        "tranmission":1,
        "drive_wheel":1, 
        "body_type":1, 
        "colour":3
    }
]
# Out:
# [{'year': 2002,
#   'manufacturer': 1,
#   'cylinder': 6,
#   'model': 1,
#   'fuel': 3,
#   'kms_driven': 1000,
#   'status': 0,
#   'tranmission': 1,
#   'drive_wheel': 1,
#   'body_type': 1,
#   'colour': 3}]
